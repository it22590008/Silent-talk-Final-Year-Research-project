# %%
from ultralytics import YOLO

model = YOLO("alphetbet.pt")  # load a pretrained model
model.export(format="tflite")
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from 'c:\ProgramData\anaconda3\lib\site-packages\typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from 'c:\ProgramData\anaconda3\lib\site-packages\typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
